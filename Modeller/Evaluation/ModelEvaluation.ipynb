# %% [markdown]
# # PDB Structures Dendrogram

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Best PDB Template = 1eh6A (PDB_Structures/1EH6.pdb)

# %% [markdown]
# # MGMT Apo Models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Lowest DOPE score = MGMT.B99990003 (Models/MGMT_Apo.pdb)

# %% [markdown]
# ------

# %% [markdown]
# # MGMT Holo Models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Lowest DOPE score = MGMT.B99990004 (Models/MGMT_Holo.pdb)

# %% [markdown]
# ------

# %% [markdown]
# # SAVES - MGMT HOLO
#
# ## ERRAT
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ## VERIFY3D
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# - At least 80% of the amino acids have scored >= 0.1 in the 3D/1D profile.
#
# ## WHATCHECK
#
# ![image-5.png](attachment:image-5.png)
#
# ## PROCHECK
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ## OVERALL RESULTS
#
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# -----

# %% [markdown]
# # SAVES MGMT APO
#
# ## ERRAT
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ## VERIFY3D
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# - At least 80% of the amino acids have scored >= 0.1 in the 3D/1D profile.
#
# ## WHATCHECK
#
# ![image-6.png](attachment:image-6.png)
#
# ## PROCHECK
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ## OVERALL RESULTS
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ----

# %% [markdown]
# # MolProbity - Apo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ----

# %% [markdown]
# # MolProbity - Holo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# -----

# %% [markdown]
# # ProSA-Web Apo
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ----

# %% [markdown]
# # ProSA-Web Holo
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# -----
